# %% [markdown]
# ## **Contributors**
# - Anirudh Gupta (055003)
# - Devansh Pratap Singh (055037)
# - Amartya Raj Singh (055053)
# - Harsh Jain (055018)

# %% [markdown]
# # Project Description: Banking App Review Sentiment and Topic Analysis
#
# ## Project Details:
# This project involves performing a detailed sentiment and topic analysis on banking application reviews for HDFC Bank and Yono SBI. The primary goal is to understand user perceptions, identify key areas of satisfaction and dissatisfaction, and categorize common pain points using advanced Natural Language Processing (NLP) techniques.
#
# ## Problem Statements:
# 1.  To understand the overall sentiment (positive, negative, neutral) of user reviews for HDFC Bank and Yono SBI mobile applications.
# 2.  To identify and compare the effectiveness of traditional (VADER) versus advanced (RoBERTa) sentiment analysis models in classifying banking app reviews.
# 3.  To pinpoint specific themes and recurring issues in both positive and negative reviews for each bank.
# 4.  To uncover latent groupings of negative feedback (pain points) across both banking apps through clustering, enabling a deeper understanding of user grievances.
#
# ## Key Activities:
# 1.  **Data Loading and Preprocessing:** Loading review data from CSV files for HDFC Bank and Yono SBI, and initial cleaning.
# 2.  **VADER Sentiment Analysis:** Applying VADER (Valence Aware Dictionary and sEntiment Reasoner) to classify reviews into Positive, Negative, and Neutral sentiments for both banks.
# 3.  **RoBERTa Sentiment Analysis:** Utilizing a pre-trained RoBERTa model from Hugging Face Transformers for more nuanced sentiment classification.
# 4.  **Sentiment Comparison:** Generating a comparative table of sentiment distribution (Positive, Negative, Neutral counts) for both banks across VADER and RoBERTa models.
# 5.  **Topic Extraction:** Identifying the top 10 most frequently discussed topics within positive and negative review subsets for each bank, after refining stopwords to exclude generic sentiment words.
# 6.  **Combined Negative Review Clustering:** Combining all negative reviews from both banks, performing TF-IDF vectorization and Truncated SVD for dimensionality reduction.
# 7.  **Optimal Cluster Determination:** Employing the Elbow Method to determine the optimal number of clusters for the combined negative reviews.
# 8.  **K-Means Clustering and Interpretation:** Applying K-Means clustering and interpreting each cluster by extracting its top topics, thereby identifying distinct categories of user pain points.
#
# ## Technologies Used:
# *   **Python:** Programming language for analysis.
# *   **pandas:** For data manipulation and analysis.
# *   **numpy:** For numerical operations.
# *   **matplotlib & seaborn:** For data visualization.
# *   **nltk:** For natural language processing tasks (tokenization, stopwords, VADER sentiment).
# *   **transformers (Hugging Face):** For implementing the RoBERTa sentiment analysis model.
# *   **scikit-learn:** For TF-IDF vectorization, Truncated SVD, and K-Means clustering.
#
# ## Nature and Source of Data:
# The data consists of user reviews for banking applications. Specifically, reviews for HDFC Bank and Yono SBI were used, sourced from respective CSV files: `/content/HDFC_Bank_Reviews.csv` and `/content/Yono_SBI_Reviews.csv`. Each dataset was downsampled to the first 500 rows for efficient processing during analysis.
#
# ## Observation:
#
# ### 1. Sentiment Analysis Overview (Positive/Negative Counts):
#
# | Bank     | Method  | Positive | Negative | Neutral |
# | :------- | :------ | :------- | :------- | :------ |
# | HDFC     | VADER   | 350      | 88       | 62      |
# | HDFC     | RoBERTa | 269      | 133      | 98      |
# | Yono SBI | VADER   | 255      | 149      | 96      |
# | Yono SBI | RoBERTa | 178      | 216      | 106     |
#
# *   **HDFC Bank:** VADER identifies a significantly higher number of positive reviews (350) compared to RoBERTa (269). RoBERTa classifies more reviews as Negative (133) and Neutral (98) for HDFC.
# *   **Yono SBI:** VADER shows more positive reviews (255) than negative (149). In contrast, RoBERTa identifies more negative reviews (216) than positive (178), suggesting a stricter or more accurate negative sentiment detection for Yono SBI.
#
# ### 2. Cluster Topics from Combined Negative Sentiments (Ranked by Strength/Size):
#
# **Total Negative Reviews Clustered:** 349
#
# 1.  **Cluster 2: Core App Functionality & Login Issues (Largest Cluster)**
#     *   **Number of Reviews:** 225
#     *   **Top Keywords:** `app`, `update`, `new`, `time`, `bank`, `login`, `one`, `open`, `account`, `issue`
#     *   **Interpretation:** This is the most prevalent pain point, focusing on fundamental app problems, especially concerning updates, login difficulties, and accessing accounts. This cluster highlights critical issues that affect a large user base.
#
# 2.  **Cluster 4: Version Change & Usability Problems**
#     *   **Number of Reviews:** 34
#     *   **Top Keywords:** `version`, `app`, `new`, `old`, `working`, `user`, `use`, `friendly`, `cant`, `download`
#     *   **Interpretation:** Users are struggling with usability and interface changes due to new app versions, encountering difficulties in using, downloading, or finding the app user-friendly.
#
# 3.  **Cluster 3: App Not Working Properly**
#     *   **Number of Reviews:** 25
#     *   **Top Keywords:** `working`, `app`, `application`, `properly`, `update`, `always`, `also`, `every`, `new`, `mobile`
#     *   **Interpretation:** This cluster explicitly addresses performance issues where the app or application does not function correctly, often after updates and sometimes tied to mobile device compatibility.
#
# 4.  **Cluster 6: Recurring Experience & Login Issues**
#     *   **Number of Reviews:** 21
#     *   **Top Keywords:** `experience`, `app`, `update`, `login`, `new`, `show`, `working`, `unable`, `last`, `months`
#     *   **Interpretation:** This cluster signifies long-standing or repeated problems, with users reporting persistent negative experiences related to app performance, updates, and login failures over several months.
#
# 5.  **Cluster 0: Overall App/Service Issues & Difficulty**
#     *   **Number of Reviews:** 18
#     *   **Top Keywords:** `app`, `ever`, `service`, `bank`, `aap`, `seen`, `compared`, `banking`, `difficult`, `understand`
#     *   **Interpretation:** Represents general dissatisfaction with the banking app and service, often citing difficulties in understanding or navigating, and comparing unfavorably to other experiences.
#
# 6.  **Cluster 1: Outdated/Old App Version Issues**
#     *   **Number of Reviews:** 16
#     *   **Top Keywords:** `app`, `old`, `new`, `time`, `aap`, `experience`, `application`, `many`, `times`, `working`
#     *   **Interpretation:** Users express concerns about the app's version, preferring older versions or noting a decline in experience with newer ones, indicating stability or feature changes are not well-received.
#
# 7.  **Cluster 5: Disappointment with Updates/Login**
#     *   **Number of Reviews:** 10
#     *   **Top Keywords:** `disappointed`, `update`, `time`, `login`, `version`, `working`, `unable`, `account`, `every`, `want`
#     *   **Interpretation:** This smallest cluster captures reviews with strong negative sentiment and `disappointment` directly linked to app `update`s and `login` issues, often resulting in an inability to access accounts.
#
#
# # Overall Insights (Market-Level Perspective)
#
# From a competitive standpoint, this analysis highlights key gaps and opportunities in the existing banking app ecosystem:
#
# - **Authentication & access are major failure points**
#   Competitors are struggling with login reliability and account access — a critical trust factor in fintech.
#
# - **Frequent updates are harming user experience**
#   Instead of improving the product, updates are introducing bugs and reducing stability.
#
# - **Core functionality is not stable**
#   Basic features like app opening, navigation, and transactions are unreliable.
#
# - **User experience is declining over time**
#   New versions are perceived as less intuitive and less user-friendly.
#
# - **Issues are recurring, not one-time**
#   Problems persist across months, indicating weak feedback loops and poor issue resolution.
#
# ---
#
# # Strategic Recommendations (For a New Market Entrant)
#
# If you are launching a new product in this market, you can gain a strong competitive advantage by addressing these gaps:
#
# ## 1. Make Reliability Your Core Differentiator
# - Ensure **zero-failure login systems** (biometric + OTP + fallback mechanisms)
# - Focus on **high uptime and crash-free performance**
# - Build trust by making core banking functions flawless
#
# ## 2. Adopt a “Stability Over Features” Approach
# - Avoid frequent disruptive updates
# - Release **well-tested, incremental updates**
# - Use staged rollouts (beta → full release)
#
# ## 3. Deliver a Superior User Experience (UX)
# - Design a **simple, intuitive interface**
# - Reduce steps for key actions (login, transfer, account view)
# - Prioritize **ease of use for non-tech-savvy users**
#
# ## 4. Build Strong Feedback & Resolution Systems
# - Implement **real-time issue tracking and resolution**
# - Actively respond to user complaints
# - Use feedback loops to continuously improve
#
# ## 5. Ensure Cross-Device Compatibility
# - Optimize for **all mobile devices and OS versions**
# - Test extensively across low-end and high-end devices (important for Indian market)
#
# ## 6. Position Your Brand Around Trust & Consistency
# - Market your app as:
#   - “Reliable”
#   - “Always accessible”
#   - “Hassle-free banking”
# - Trust is a major differentiator in financial services
#
# ---
#
#
# > **Key Takeaway:**
# > The biggest opportunity in this market is not innovation, but **execution excellence** — delivering a stable, reliable, and user-friendly product where competitors are currently failing.

# %%
# Get sentiment labels and visualize for RoBERTa on Yono SBI Reviews
def get_roberta_sentiment_label(neg_score, neu_score, pos_score):
    # Determine the label based on the highest score
    if pos_score > neg_score and pos_score > neu_score:
        return 'Positive'
    elif neg_score > pos_score and neg_score > neu_score:
        return 'Negative'
    else:
        return 'Neutral'

# Apply categorization to Yono SBI reviews using RoBERTa scores
aa04_df_sbi['roberta_sentiment_label'] = aa04_df_sbi.apply(lambda row: get_roberta_sentiment_label(row['roberta_neg'], row['roberta_neu'], row['roberta_pos']), axis=1)

print("Sentiment Distribution (RoBERTa) for Yono SBI Reviews:")
print(aa04_df_sbi['roberta_sentiment_label'].value_counts())

# Visualize the sentiment distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='roberta_sentiment_label', data=aa04_df_sbi, palette='viridis', hue='roberta_sentiment_label', legend=False)
plt.title('RoBERTa Sentiment Analysis Distribution for Yono SBI Reviews')
plt.xlabel('Sentiment')
plt.ylabel('Number of Reviews')
plt.show()
# Out:
# Sentiment Distribution (RoBERTa) for Yono SBI Reviews:
# roberta_sentiment_label
# Negative    216
# Positive    178
# Neutral     106
# Name: count, dtype: int64

# %%
# Get sentiment labels and visualize for RoBERTa on HDFC Bank Reviews
def get_roberta_sentiment_label(neg_score, neu_score, pos_score):
    # Determine the label based on the highest score
    if pos_score > neg_score and pos_score > neu_score:
        return 'Positive'
    elif neg_score > pos_score and neg_score > neu_score:
        return 'Negative'
    else:
        return 'Neutral'

# Apply categorization to HDFC reviews using RoBERTa scores
aa04_df_hdfc['roberta_sentiment_label'] = aa04_df_hdfc.apply(lambda row: get_roberta_sentiment_label(row['roberta_neg'], row['roberta_neu'], row['roberta_pos']), axis=1)

print("Sentiment Distribution (RoBERTa) for HDFC Bank Reviews:")
print(aa04_df_hdfc['roberta_sentiment_label'].value_counts())

# Visualize the sentiment distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='roberta_sentiment_label', data=aa04_df_hdfc, palette='viridis', hue='roberta_sentiment_label', legend=False)
plt.title('RoBERTa Sentiment Analysis Distribution for HDFC Bank Reviews')
plt.xlabel('Sentiment')
plt.ylabel('Number of Reviews')
plt.show()
# Out:
# Sentiment Distribution (RoBERTa) for HDFC Bank Reviews:
# roberta_sentiment_label
# Positive    269
# Negative    133
# Neutral      98
# Name: count, dtype: int64

# %%
# Apply VADER sentiment analysis to Yono SBI reviews to ensure 'compound' is present
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

def get_vader_sentiment(text):
    if isinstance(text, str):
        return sia.polarity_scores(text)
    return {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}

# Ensure aa04_df_sbi is up-to-date with VADER scores
aa04_df_sbi['vader_sentiment'] = aa04_df_sbi['content'].apply(get_vader_sentiment)
aa04_df_sbi = pd.concat([aa04_df_sbi.drop(['vader_sentiment'], axis=1), aa04_df_sbi['vader_sentiment'].apply(pd.Series)], axis=1)

# Apply categorization to Yono SBI reviews
aa04_df_sbi['vader_sentiment_label'] = aa04_df_sbi['compound'].apply(get_sentiment_label)

print("Sentiment Distribution (VADER) for Yono SBI Reviews:")
print(aa04_df_sbi['vader_sentiment_label'].value_counts())

# Visualize the sentiment distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='vader_sentiment_label', data=aa04_df_sbi, palette='viridis', hue='vader_sentiment_label', legend=False)
plt.title('VADER Sentiment Analysis Distribution for Yono SBI Reviews')
plt.xlabel('Sentiment')
plt.ylabel('Number of Reviews')
plt.show()
# Out:
# Sentiment Distribution (VADER) for Yono SBI Reviews:
# vader_sentiment_label
# Positive    255
# Negative    149
# Neutral      96
# Name: count, dtype: int64

# %%
# Function to categorize sentiment based on compound score
def get_sentiment_label(compound_score):
    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# Apply categorization to HDFC reviews
aa04_df_hdfc['vader_sentiment_label'] = aa04_df_hdfc['compound'].apply(get_sentiment_label)

print("Sentiment Distribution (VADER) for HDFC Bank Reviews:")
print(aa04_df_hdfc['vader_sentiment_label'].value_counts())

# Visualize the sentiment distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='vader_sentiment_label', data=aa04_df_hdfc, palette='viridis', hue='vader_sentiment_label', legend=False)
plt.title('VADER Sentiment Analysis Distribution for HDFC Bank Reviews')
plt.xlabel('Sentiment')
plt.ylabel('Number of Reviews')
plt.show()
# Out:
# Sentiment Distribution (VADER) for HDFC Bank Reviews:
# vader_sentiment_label
# Positive    350
# Negative     88
# Neutral      62
# Name: count, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Step 1: Vectorize the text data using TF-IDF
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(all_negative_reviews)

print(f"Shape of TF-IDF matrix: {X.shape}")

# Step 2: Apply Dimensionality Reduction (LSA using TruncatedSVD)
# Reduce to a reasonable number of components, e.g., 100
svd = TruncatedSVD(n_components=100, random_state=42)
X_reduced = svd.fit_transform(X)

print(f"Shape of reduced data: {X_reduced.shape}")

# Step 3: Determine the optimum number of clusters using the Elbow Method
# Test a range of cluster numbers (e.g., 1 to 10)
inertia = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=42)
    kmeans.fit(X_reduced)
    inertia.append(kmeans.inertia_)

# Plot the Elbow Method graph
plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), inertia, marker='o')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.xticks(range(1, 11))
plt.grid(True)
plt.show()

print("Please examine the elbow plot above to identify the optimal number of clusters.")
# Out:
# Shape of TF-IDF matrix: (349, 988)
# Shape of reduced data: (349, 100)
# Please examine the elbow plot above to identify the optimal number of clusters.

# %%
print("\n--- Yono SBI Reviews (RoBERTa) ---")
yono_sbi_positive_reviews = aa04_df_sbi[aa04_df_sbi['roberta_sentiment_label'] == 'Positive']['content']
yono_sbi_negative_reviews = aa04_df_sbi[aa04_df_sbi['roberta_sentiment_label'] == 'Negative']['content']

print("\nTop 10 Positive Topics (Yono SBI):")
display(get_top_topics(yono_sbi_positive_reviews))

print("\nTop 10 Negative Topics (Yono SBI):")
display(get_top_topics(yono_sbi_negative_reviews))
# Out:
# --- Yono SBI Reviews (RoBERTa) ---
#
# Top 10 Positive Topics (Yono SBI):
# [('app', 27),
#  ('service', 7),
#  ('sbi', 6),
#  ('work', 6),
#  ('yono', 6),
#  ('banking', 5),
#  ('easy', 4),
#  ('well', 4),
#  ('services', 3),
#  ('awesome', 3)]
# Top 10 Negative Topics (Yono SBI):
# [('app', 150),
#  ('update', 48),
#  ('working', 41),
#  ('time', 39),
#  ('login', 35),
#  ('new', 30),
#  ('version', 28),
#  ('open', 25),
#  ('account', 25),
#  ('sbi', 25)]

# %%
# Step 4: Apply K-Means Clustering with 7 clusters
optimal_clusters = 7 # Based on user's input from Elbow Method
kmeans = KMeans(n_clusters=optimal_clusters, init='k-means++', max_iter=300, n_init=10, random_state=42)
all_negative_reviews_df = pd.DataFrame(all_negative_reviews, columns=['content'])
all_negative_reviews_df['cluster'] = kmeans.fit_predict(X_reduced)

print(f"Clustering complete. {optimal_clusters} clusters formed.")
print("Cluster distribution:")
display(all_negative_reviews_df['cluster'].value_counts().sort_index())

# Step 5: Interpret the clusters by identifying top topics in each cluster
print("\n--- Top Topics for Each Cluster (7 Clusters) ---")
for i in range(optimal_clusters):
    cluster_reviews = all_negative_reviews_df[all_negative_reviews_df['cluster'] == i]['content']
    print(f"\nCluster {i} ({len(cluster_reviews)} reviews):") # Removed extra newline for cleaner output during programmatic capture if needed
    print(get_top_topics(cluster_reviews)) # Use print instead of display for full output capture
# Out:
# Clustering complete. 7 clusters formed.
# Cluster distribution:
# cluster
# 0     18
# 1     16
# 2    225
# 3     25
# 4     34
# 5     10
# 6     21
# Name: count, dtype: int64
# --- Top Topics for Each Cluster (7 Clusters) ---
#
# Cluster 0 (18 reviews):
# [('app', 13), ('ever', 4), ('service', 3), ('bank', 2), ('aap', 2), ('seen', 1), ('compared', 1), ('banking', 1), ('difficult', 1), ('understand', 1)]
#
# Cluster 1 (16 reviews):
# [('app', 7), ('old', 6), ('new', 4), ('time', 2), ('aap', 2), ('experience', 2), ('application', 2), ('many', 1), ('times', 1), ('working', 1)]
#
# Cluster 2 (225 reviews):
# [('app', 214), ('update', 44), ('new', 41), ('time', 39), ('bank', 34), ('login', 34), ('one', 30), ('open', 28), ('account', 27), ('issue', 26)]
#
# Cluster 3 (25 reviews):
# [('working', 30), ('app', 10), ('application', 8), ('properly', 4), ('update', 3), ('always', 3), ('also', 3), ('every', 3), ('new', 2), ('mobile', 2)]
#
# Cluster 4 (34 reviews):
# ...

# %%
# Combine all negative reviews from both banks
all_negative_reviews = pd.concat([hdfc_negative_reviews, yono_sbi_negative_reviews], ignore_index=True)

print(f"Total number of negative reviews for clustering: {len(all_negative_reviews)}")
print("First 5 combined negative reviews:")
display(all_negative_reviews.head())
# Out:
# Total number of negative reviews for clustering: 349
# First 5 combined negative reviews:
# 0               not supporting motorola edge 50 fusion
# 1    The app has become pathetic for a while now. H...
# 2    There is bug in application. Every time it is ...
# 3    Facing Error-sorry unable to connect server, p...
# 4    No mobile app is working. When I put pin it op...
# Name: content, dtype: object

# %%
print("\n--- Common Negative Topics (RoBERTa) ---")

# Combine negative reviews from both banks
common_negative_reviews = pd.concat([hdfc_negative_reviews, yono_sbi_negative_reviews])

print("\nTop 10 Common Negative Topics Across Both Banks:")
display(get_top_topics(common_negative_reviews))
# Out:
# --- Common Negative Topics (RoBERTa) ---
#
# Top 10 Common Negative Topics Across Both Banks:
# [('app', 280),
#  ('new', 82),
#  ('version', 78),
#  ('working', 67),
#  ('update', 59),
#  ('time', 51),
#  ('login', 43),
#  ('bank', 40),
#  ('one', 37),
#  ('old', 33)]

# %%
print("\n--- Yono SBI Reviews (RoBERTa) ---")
yono_sbi_positive_reviews = aa04_df_sbi[aa04_df_sbi['roberta_sentiment_label'] == 'Positive']['content']
yono_sbi_negative_reviews = aa04_df_sbi[aa04_df_sbi['roberta_sentiment_label'] == 'Negative']['content']

print("\nTop 10 Positive Topics (Yono SBI):")
display(get_top_topics(yono_sbi_positive_reviews))

print("\nTop 10 Negative Topics (Yono SBI):")
display(get_top_topics(yono_sbi_negative_reviews))
# Out:
# --- Yono SBI Reviews (RoBERTa) ---
#
# Top 10 Positive Topics (Yono SBI):
# [('app', 27),
#  ('service', 7),
#  ('sbi', 6),
#  ('work', 6),
#  ('yono', 6),
#  ('banking', 5),
#  ('easy', 4),
#  ('well', 4),
#  ('services', 3),
#  ('awesome', 3)]
# Top 10 Negative Topics (Yono SBI):
# [('app', 150),
#  ('update', 48),
#  ('working', 41),
#  ('time', 39),
#  ('login', 35),
#  ('new', 30),
#  ('version', 28),
#  ('open', 25),
#  ('account', 25),
#  ('sbi', 25)]

# %%
print("\n--- Common Negative Topics (RoBERTa) ---")

# Combine negative reviews from both banks
common_negative_reviews = pd.concat([hdfc_negative_reviews, yono_sbi_negative_reviews])

print("\nTop 10 Common Negative Topics Across Both Banks:")
display(get_top_topics(common_negative_reviews))
# Out:
# --- Common Negative Topics (RoBERTa) ---
#
# Top 10 Common Negative Topics Across Both Banks:
# [('app', 280),
#  ('new', 82),
#  ('version', 78),
#  ('working', 67),
#  ('update', 59),
#  ('time', 51),
#  ('login', 43),
#  ('bank', 40),
#  ('one', 37),
#  ('old', 33)]

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
from collections import Counter

# Download stopwords if not already downloaded
try:
    stopwords.words('english')
except LookupError:
    nltk.download('stopwords')
try:
    word_tokenize('test')
except LookupError:
    nltk.download('punkt')

# Explicitly download punkt_tab as it's required by the PunktTokenizer
try:
    nltk.data.find('tokenizers/punkt_tab/english/')
except LookupError:
    nltk.download('punkt_tab')

stop_words = set(stopwords.words('english'))

# Add generic sentiment words that are not useful as 'topics'
generic_sentiment_words = {'good', 'bad', 'please', 'worst', 'nice', 'great', 'excellent', 'best', 'better'}
stop_words.update(generic_sentiment_words)

def preprocess_text(text):
    if not isinstance(text, str): # Handle non-string input
        return []
    text = text.lower() # Convert to lowercase
    text = text.translate(str.maketrans('', '', string.punctuation)) # Remove punctuation
    tokens = word_tokenize(text) # Tokenize text
    # Remove stopwords and non-alphabetic tokens
    filtered_tokens = [word for word in tokens if word.isalpha() and word not in stop_words]
    return filtered_tokens

def get_top_topics(reviews_series, num_topics=10):
    all_tokens = []
    for review in reviews_series:
        all_tokens.extend(preprocess_text(review))

    # Count word frequencies
    word_counts = Counter(all_tokens)
    return word_counts.most_common(num_topics)

# --- HDFC Bank Reviews ---
print("\n--- HDFC Bank Reviews (RoBERTa) ---")
hdfc_positive_reviews = aa04_df_hdfc[aa04_df_hdfc['roberta_sentiment_label'] == 'Positive']['content']
hdfc_negative_reviews = aa04_df_hdfc[aa04_df_hdfc['roberta_sentiment_label'] == 'Negative']['content']

print("\nTop 10 Positive Topics (HDFC Bank):")
display(get_top_topics(hdfc_positive_reviews))

print("\nTop 10 Negative Topics (HDFC Bank):")
display(get_top_topics(hdfc_negative_reviews))

# --- Yono SBI Reviews ---
print("\n--- Yono SBI Reviews (RoBERTa) ---")
yono_sbi_positive_reviews = aa04_df_sbi[aa04_df_sbi['roberta_sentiment_label'] == 'Positive']['content']
yono_sbi_negative_reviews = aa04_df_sbi[aa04_df_sbi['roberta_sentiment_label'] == 'Negative']['content']

print("\nTop 10 Positive Topics (Yono SBI):")
display(get_top_topics(yono_sbi_positive_reviews))

print("\nTop 10 Negative Topics (Yono SBI):")
display(get_top_topics(yono_sbi_negative_reviews))
# Out:
# --- HDFC Bank Reviews (RoBERTa) ---
#
# Top 10 Positive Topics (HDFC Bank):
# [('app', 104),
#  ('version', 42),
#  ('new', 36),
#  ('old', 32),
#  ('user', 16),
#  ('friendly', 16),
#  ('easy', 16),
#  ('bank', 15),
#  ('one', 15),
#  ('use', 14)]
# Top 10 Negative Topics (HDFC Bank):
# [('app', 130),
#  ('new', 52),
#  ('version', 50),
#  ('old', 28),
#  ('hdfc', 27),
#  ('working', 26),
#  ('bank', 22),
#  ('one', 22),
#  ('mobile', 14),
#  ('time', 12)]
# --- Yono SBI Reviews (RoBERTa) ---
#
# Top 10 Positive Topics (Yono SBI):
# [('app', 27),
#  ('service', 7),
#  ('sbi', 6),
#  ('work', 6),
#  ('yono', 6),
#  ('banking', 5),
#  ('easy', 4),
#  ('well', 4),
#  ('services', 3),
#  ('awesome', 3)]
# Top 10 Negative Topics (Yono SBI):
# [('app', 150),
#  ('update', 48),
#  ('working', 41),
#  ('time', 39),
#  ('login', 35),
#  ('new', 30),
#  ('version', 28),
#  ('open', 25),
#  ('account', 25),
#  ('sbi', 25)]

# %%
results = []

# HDFC VADER results
hdfc_vader_counts = aa04_df_hdfc['vader_sentiment_label'].value_counts()
results.append({
    'Bank': 'HDFC',
    'Method': 'VADER',
    'Positive': hdfc_vader_counts.get('Positive', 0),
    'Negative': hdfc_vader_counts.get('Negative', 0),
    'Neutral': hdfc_vader_counts.get('Neutral', 0)
})

# HDFC RoBERTa results
hdfc_roberta_counts = aa04_df_hdfc['roberta_sentiment_label'].value_counts()
results.append({
    'Bank': 'HDFC',
    'Method': 'RoBERTa',
    'Positive': hdfc_roberta_counts.get('Positive', 0),
    'Negative': hdfc_roberta_counts.get('Negative', 0),
    'Neutral': hdfc_roberta_counts.get('Neutral', 0)
})

# Yono SBI VADER results
yono_sbi_vader_counts = aa04_df_sbi['vader_sentiment_label'].value_counts()
results.append({
    'Bank': 'Yono SBI',
    'Method': 'VADER',
    'Positive': yono_sbi_vader_counts.get('Positive', 0),
    'Negative': yono_sbi_vader_counts.get('Negative', 0),
    'Neutral': yono_sbi_vader_counts.get('Neutral', 0)
})

# Yono SBI RoBERTa results
yono_sbi_roberta_counts = aa04_df_sbi['roberta_sentiment_label'].value_counts()
results.append({
    'Bank': 'Yono SBI',
    'Method': 'RoBERTa',
    'Positive': yono_sbi_roberta_counts.get('Positive', 0),
    'Negative': yono_sbi_roberta_counts.get('Negative', 0),
    'Neutral': yono_sbi_roberta_counts.get('Neutral', 0)
})

comparison_df = pd.DataFrame(results)

print("Sentiment Analysis Comparison Table:")
display(comparison_df)
# Out:
# Sentiment Analysis Comparison Table:
#        Bank   Method  Positive  Negative  Neutral
# 0      HDFC    VADER       350        88       62
# 1      HDFC  RoBERTa       269       133       98
# 2  Yono SBI    VADER       255       149       96
# 3  Yono SBI  RoBERTa       178       216      106

# %%
# Get sentiment labels and visualize for RoBERTa on Yono SBI Reviews
def get_roberta_sentiment_label(neg_score, neu_score, pos_score):
    # Determine the label based on the highest score
    if pos_score > neg_score and pos_score > neu_score:
        return 'Positive'
    elif neg_score > pos_score and neg_score > neu_score:
        return 'Negative'
    else:
        return 'Neutral'

# Before applying categorization, ensure the DataFrame columns are unique.
# This prevents errors if roberta analysis was run multiple times, creating duplicate columns.
# We'll drop duplicate columns keeping the last ones (most recent computation).
if any(aa04_df_sbi.columns.duplicated()):
    aa04_df_sbi = aa04_df_sbi.loc[:, ~aa04_df_sbi.columns.duplicated(keep='last')]

# Apply categorization to Yono SBI reviews using RoBERTa scores
aa04_df_sbi['roberta_sentiment_label'] = aa04_df_sbi.apply(lambda row: get_roberta_sentiment_label(row['roberta_neg'], row['roberta_neu'], row['roberta_pos']), axis=1)

print("Sentiment Distribution (RoBERTa) for Yono SBI Reviews:")
print(aa04_df_sbi['roberta_sentiment_label'].value_counts())

# Visualize the sentiment distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='roberta_sentiment_label', data=aa04_df_sbi, palette='viridis', hue='roberta_sentiment_label', legend=False)
plt.title('RoBERTa Sentiment Analysis Distribution for Yono SBI Reviews')
plt.xlabel('Sentiment')
plt.ylabel('Number of Reviews')
plt.show()
# Out:
# Sentiment Distribution (RoBERTa) for Yono SBI Reviews:
# roberta_sentiment_label
# Negative    216
# Positive    178
# Neutral     106
# Name: count, dtype: int64

# %%
# Apply RoBERTa sentiment analysis to Yono SBI reviews
aa04_df_sbi['roberta_sentiment'] = aa04_df_sbi['content'].apply(get_roberta_sentiment)
# Expand the dictionary of scores into separate columns in the DataFrame
aa04_df_sbi = pd.concat([aa04_df_sbi.drop(['roberta_sentiment'], axis=1), aa04_df_sbi['roberta_sentiment'].apply(pd.Series)], axis=1)

print("First 5 rows of Yono SBI Reviews with RoBERTa scores:")
display(aa04_df_sbi.head())
# Out:
# First 5 rows of Yono SBI Reviews with RoBERTa scores:
# /tmp/ipykernel_4661/3275500239.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sbi['roberta_sentiment'] = df_sbi['content'].apply(get_roberta_sentiment)
#                                reviewId                  userName  \
# 0  dff2b073-3614-4669-8099-11be037e1f23          Dilshad ali khan
# 1  0558ca92-a307-4b8a-8079-cd4735d58f10     Jaya priya Jaya priya
# 2  46d239d0-4796-4920-881f-62bf5f1b44c0         Chaitanya Krishna
# 3  0bfa1c19-d1b3-4932-bd9a-842a72b31e27  Dhinakaran R Kolandavelu
# 4  491d6edc-4870-4036-97cb-9658feeb825a                Rina Bains
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %%
# Apply RoBERTa sentiment analysis to Yono SBI reviews
aa04_df_sbi['roberta_sentiment'] = aa04_df_sbi['content'].apply(get_roberta_sentiment)
# Expand the dictionary of scores into separate columns in the DataFrame
aa04_df_sbi = pd.concat([aa04_df_sbi.drop(['roberta_sentiment'], axis=1), aa04_df_sbi['roberta_sentiment'].apply(pd.Series)], axis=1)

print("First 5 rows of Yono SBI Reviews with RoBERTa scores:")
display(aa04_df_sbi.head())
# Out:
# First 5 rows of Yono SBI Reviews with RoBERTa scores:
# /tmp/ipykernel_4661/3275500239.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sbi['roberta_sentiment'] = df_sbi['content'].apply(get_roberta_sentiment)
#                                reviewId                  userName  \
# 0  dff2b073-3614-4669-8099-11be037e1f23          Dilshad ali khan
# 1  0558ca92-a307-4b8a-8079-cd4735d58f10     Jaya priya Jaya priya
# 2  46d239d0-4796-4920-881f-62bf5f1b44c0         Chaitanya Krishna
# 3  0bfa1c19-d1b3-4932-bd9a-842a72b31e27  Dhinakaran R Kolandavelu
# 4  491d6edc-4870-4036-97cb-9658feeb825a                Rina Bains
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %%
# Install necessary libraries for Hugging Face Transformers
# !pip install transformers torch

# Import libraries for Roberta model
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from scipy.special import softmax

# Load pre-trained RoBERTa model and tokenizer
task = 'sentiment'
model_name = f"cardiffnlp/twitter-roberta-base-{task}"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# Function to get RoBERTa sentiment scores
def get_roberta_sentiment(text):
    if isinstance(text, str) and text.strip(): # Check if text is a non-empty string
        # Encode the text, ensuring truncation if it's too long for the model
        encoded_text = tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
        # Pass the encoded text through the model
        output = model(**encoded_text)
        # Extract and apply softmax to the logits to get probabilities
        scores = output[0][0].detach().numpy()
        scores = softmax(scores)
        return {'roberta_neg': scores[0], 'roberta_neu': scores[1], 'roberta_pos': scores[2]}
    # Return default scores for non-string or empty inputs
    return {'roberta_neg': 0.0, 'roberta_neu': 0.0, 'roberta_pos': 0.0}

# Apply RoBERTa sentiment analysis to HDFC reviews
aa04_df_hdfc['roberta_sentiment'] = aa04_df_hdfc['content'].apply(get_roberta_sentiment)
# Expand the dictionary of scores into separate columns in the DataFrame
aa04_df_hdfc = pd.concat([aa04_df_hdfc.drop(['roberta_sentiment'], axis=1), aa04_df_hdfc['roberta_sentiment'].apply(pd.Series)], axis=1)

print("First 5 rows of HDFC Bank Reviews with RoBERTa scores:")
display(aa04_df_hdfc.head())
# Out:
# ...
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: cardiffnlp/twitter-roberta-base-sentiment
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# First 5 rows of HDFC Bank Reviews with RoBERTa scores:
#                                reviewId          userName  \
# 0  2267f64f-3059-454b-b6a6-fcd2b57cb09c           BK211 G
# 1  0907ae45-7150-4460-8d3b-929cc6faa140      Vinod Sharma
# 2  2016c3cc-2d5d-49fe-9425-46058eabbc64            Rani K
# 3  3fb46e2d-733a-4b10-91c9-0104c2e1942d       Rashid Khan
# 4  e06f0ecf-196a-49e2-a7ae-460fa9ced398  gaurvendra singh
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# ...

# %%
# Apply VADER sentiment analysis to Yono SBI reviews
aa04_df_sbi['vader_sentiment'] = aa04_df_sbi['content'].apply(get_vader_sentiment)

aa04_df_sbi = pd.concat([aa04_df_sbi.drop(['vader_sentiment'], axis=1), aa04_df_sbi['vader_sentiment'].apply(pd.Series)], axis=1)

print("First 5 rows of Yono SBI Reviews with VADER scores:")
display(aa04_df_sbi.head())
# Out:
# First 5 rows of Yono SBI Reviews with VADER scores:
#                                reviewId                  userName  \
# 0  dff2b073-3614-4669-8099-11be037e1f23          Dilshad ali khan
# 1  0558ca92-a307-4b8a-8079-cd4735d58f10     Jaya priya Jaya priya
# 2  46d239d0-4796-4920-881f-62bf5f1b44c0         Chaitanya Krishna
# 3  0bfa1c19-d1b3-4932-bd9a-842a72b31e27  Dhinakaran R Kolandavelu
# 4  491d6edc-4870-4036-97cb-9658feeb825a                Rina Bains
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0                                              thank      5              0
# ...

# %%
# Apply VADER sentiment analysis to HDFC reviews
aa04_df_hdfc['vader_sentiment'] = aa04_df_hdfc['content'].apply(get_vader_sentiment)

aa04_df_hdfc = pd.concat([aa04_df_hdfc.drop(['vader_sentiment'], axis=1), aa04_df_hdfc['vader_sentiment'].apply(pd.Series)], axis=1)

print("First 5 rows of HDFC Bank Reviews with VADER scores:")
display(aa04_df_hdfc.head())
# Out:
# First 5 rows of HDFC Bank Reviews with VADER scores:
#                                reviewId          userName  \
# 0  2267f64f-3059-454b-b6a6-fcd2b57cb09c           BK211 G
# 1  0907ae45-7150-4460-8d3b-929cc6faa140      Vinod Sharma
# 2  2016c3cc-2d5d-49fe-9425-46058eabbc64            Rani K
# 3  3fb46e2d-733a-4b10-91c9-0104c2e1942d       Rashid Khan
# 4  e06f0ecf-196a-49e2-a7ae-460fa9ced398  gaurvendra singh
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0                                                 ??      1              0
# 1                                        good surves      5              0
# ...

# %%
# Download NLTK resources for Vader
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

def get_vader_sentiment(text):
    if isinstance(text, str):
        return sia.polarity_scores(text)
    return {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read in Yono SBI Reviews data
aa04_df_sbi = pd.read_csv('/content/Yono_SBI_Reviews.csv', encoding='latin1')
aa04_df_sbi = aa04_df_sbi.head(500) # Downsample to first 500 rows
print("Shape of Yono SBI Reviews:", aa04_df_sbi.shape)
print("First 5 rows of Yono SBI Reviews:")
display(aa04_df_sbi.head())
# Out:
# Shape of Yono SBI Reviews: (500, 11)
# First 5 rows of Yono SBI Reviews:
#                                reviewId                  userName  \
# 0  dff2b073-3614-4669-8099-11be037e1f23          Dilshad ali khan
# 1  0558ca92-a307-4b8a-8079-cd4735d58f10     Jaya priya Jaya priya
# 2  46d239d0-4796-4920-881f-62bf5f1b44c0         Chaitanya Krishna
# 3  0bfa1c19-d1b3-4932-bd9a-842a72b31e27  Dhinakaran R Kolandavelu
# 4  491d6edc-4870-4036-97cb-9658feeb825a                Rina Bains
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0                                              thank      5              0
# ...

# %%
# Read in HDFC Bank Reviews data
aa04_df_hdfc = pd.read_csv('/content/HDFC_Bank_Reviews.csv', encoding='latin1')
aa04_df_hdfc = aa04_df_hdfc.head(500) # Downsample to first 500 rows
print("Shape of HDFC Bank Reviews:", aa04_df_hdfc.shape)
print("First 5 rows of HDFC Bank Reviews:")
display(aa04_df_hdfc.head())
# Out:
# Shape of HDFC Bank Reviews: (500, 11)
# First 5 rows of HDFC Bank Reviews:
#                                reviewId          userName  \
# 0  2267f64f-3059-454b-b6a6-fcd2b57cb09c           BK211 G
# 1  0907ae45-7150-4460-8d3b-929cc6faa140      Vinod Sharma
# 2  2016c3cc-2d5d-49fe-9425-46058eabbc64            Rani K
# 3  3fb46e2d-733a-4b10-91c9-0104c2e1942d       Rashid Khan
# 4  e06f0ecf-196a-49e2-a7ae-460fa9ced398  gaurvendra singh
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0                                                 ??      1              0
# ...

# %%
# Import libraries as per assignment
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk

# Set a style for plots
sns.set_style('darkgrid')
